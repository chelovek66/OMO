# %% [markdown]
# <a href="https://colab.research.google.com/github/chelovek66/OMO/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# Out:
# ...
# [I 03:43:51 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 03:43:51 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 03:43:51 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.11/dist-packages/jupyter_contrib_nbextensions/nbextensions/zenmode -> zenmode
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/zenmode.yaml
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/main.js
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/README.md
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/main.css
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back11.jpg
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=20000)

# %%
x_train = pad_sequences(x_train, maxlen=100, padding='post', truncating='post')
x_test = pad_sequences(x_test, maxlen=100, padding='post', truncating='post')

# %%
model = tf.keras.models.Sequential([
    layers.Embedding(input_dim=20000 ,output_dim=128, input_shape =(100,)),
    layers.LSTM(units=128, activation='tanh'),
    layers.Dense(units=1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 128)       │     2,560,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,691,713 (10.27 MB)
#  Trainable params: 2,691,713 (10.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,batch_size=128,epochs=5,validation_data=(x_test,y_test))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 104s 509ms/step - accuracy: 0.5260 - loss: 0.6892 - val_accuracy: 0.6806 - val_loss: 0.6371
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 153s 568ms/step - accuracy: 0.7378 - loss: 0.5478 - val_accuracy: 0.7584 - val_loss: 0.5676
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 144s 577ms/step - accuracy: 0.8181 - loss: 0.4329 - val_accuracy: 0.8100 - val_loss: 0.4739
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 141s 572ms/step - accuracy: 0.8557 - loss: 0.3619 - val_accuracy: 0.8136 - val_loss: 0.4457
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 142s 574ms/step - accuracy: 0.8806 - loss: 0.3168 - val_accuracy: 0.8154 - val_loss: 0.4337

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.8165 - loss: 0.4307

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
