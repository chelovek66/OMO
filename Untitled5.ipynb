# %% [markdown]
# <a href="https://colab.research.google.com/github/chelovek66/OMO/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# Out:
# ...
# [I 03:43:51 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 03:43:51 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 03:43:51 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.11/dist-packages/jupyter_contrib_nbextensions/nbextensions/zenmode -> zenmode
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/zenmode.yaml
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/main.js
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/README.md
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/main.css
# [I 03:43:51 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back11.jpg
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=10000)

# %%
x_train = pad_sequences(x_train, maxlen=120, padding='post', truncating='post')
x_test = pad_sequences(x_test, maxlen=120, padding='post', truncating='post')

# %%
model = tf.keras.models.Sequential([
    layers.Embedding(input_dim=10000 ,output_dim=128, input_shape =(120,)),
    layers.LSTM(units=64, activation='tanh'),
    layers.Dense(units=1, activation='sigmoid')
])

# %%
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,batch_size=128,epochs=5,validation_data=(x_test,y_test))
# Out:
# Epoch 1/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 77s 377ms/step - accuracy: 0.5306 - loss: 0.6865 - val_accuracy: 0.7117 - val_loss: 0.5757
# Epoch 2/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 79s 360ms/step - accuracy: 0.7563 - loss: 0.5312 - val_accuracy: 0.8080 - val_loss: 0.4587
# Epoch 3/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 78s 338ms/step - accuracy: 0.8297 - loss: 0.4179 - val_accuracy: 0.7421 - val_loss: 0.5271
# Epoch 4/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 86s 358ms/step - accuracy: 0.8532 - loss: 0.3702 - val_accuracy: 0.8302 - val_loss: 0.4004
# Epoch 5/5
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 77s 335ms/step - accuracy: 0.8636 - loss: 0.3437 - val_accuracy: 0.8126 - val_loss: 0.4241

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.8148 - loss: 0.4226

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 120, 128)       │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,658,948 (10.14 MB)
#  Trainable params: 1,329,473 (5.07 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,329,475 (5.07 MB)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
